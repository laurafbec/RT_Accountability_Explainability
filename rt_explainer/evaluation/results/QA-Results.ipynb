# %%
import pandas as pd

# %%
dataset_scn1 = pd.read_excel("QA_Results.xlsx",sheet_name = "Scn1")

# %%
dataset_scn1.head()
# Out:
#    SCENARIOID  RUNID  ExampleID  \
# 0           1    1.0          1
# 1           1    1.0          2
# 2           1    1.0          3
# 3           1    1.0          4
# 4           1    1.0          5
#
#                                           user_input  \
# 0  How many goals were successfully achieved by t...
# 1  Which ones? Look for all that have been succes...
# 2  Have all objectives been successfully achieved...
# 3  Has the robot re-planned an alternative trajec...
# 4                Why did the robot replan the route?
#
#                                   retrieved_contexts  \
# 0  ['1739992528.310764723 Navigation to the goal ...
# 1  ['1739992528.310764723 Navigation to the goal ...
# 2  ['1739992528.310764723 Navigation to the goal ...
# 3  ['1739992528.310764723 Navigation to the goal ...
# 4  ['1739992528.310764723 Navigation to the goal ...
#
#                                             response  \
# 0  The robot successfully achieved 3 goals. The c...
# ...

# %%
print(dataset_scn1['user_input'][30])
# Out:
# What is the Euclidean distance between the first position of the robot before beginning the navigation task and the first goal coordinates the robot navigates to?

# %%
print(dataset_scn1['response'][30])
# Out:
# The Euclidean distance between the initial position of the robot **(0.00, 10.00)** and the first goal coordinates **(-8.17, -5.15)** is calculated as follows:
#
# \[
# \text{Distance} = \sqrt{(-8.17 - 0.00)^2 + (-5.15 - 10.00)^2} = \sqrt{66.7489 + 229.5225} = \sqrt{296.2714} \approx 17.21 \text{ meters}.
# \]
#
# **Answer:** Approximately **17.21 meters**.

# %%
print(dataset_scn1['reference'][30])
# Out:
# The Euclidean distance between the initial position of the robot **(0.00, 10.00)** and the first goal coordinates **(-8.17, -5.15)** is approximately **17.21 units.

# %%
print(dataset_scn1['Verdict'][30])
# Out:
# 1

# %%
print(dataset_scn1['Reason'][30])
# Out:
# The response provides a detailed calculation of the Euclidean distance, resulting in approximately 17.21 meters, which is factually similar to the reference stating the distance is approximately 17.21 units.

# %%
print(f"Understability: {dataset_scn1['understability'][30]}, Satisfaction: {dataset_scn1['satisfaction'][30]}, Informativeness: {dataset_scn1['informativeness'][30]},  Completeness: {dataset_scn1['completeness'][30]},  Usefulness: {dataset_scn1['usefulness'][30]},  Coherence: {dataset_scn1['coherence'][30]}")
# Out:
# Understability: 5, Satisfaction: 5, Informativeness: 5,  Completeness: 4,  Usefulness: 5,  Coherence: 4
